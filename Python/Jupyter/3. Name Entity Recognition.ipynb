# %% [markdown]
# Name Entities Recognition, Extract and Classification using *SpaCy*

# %%
pip install spacy

# %%
#installation of spacy
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
import spacy

# %%
NER = spacy.load('en_core_web_sm')

# %%
text = "Yesterday dated 5/10/2024, Amol travelled from Mumbai to Delhi to attend conference organized by Microst oft. He travelled by Airplane and he got ticket $99. Amol's mobile number is 3524545454"

# %%
ner_text = NER(text)

# %%
for word in ner_text.ents:
  print(word.text, word.label_) #underscore na dele result miliba nahi
# Out:
# Yesterday DATE
# 5/10/2024 DATE
# Amol PERSON
# Mumbai GPE
# Delhi GPE
# Microst PERSON
# Airplane GPE
# 99 MONEY
# Amol PERSON
# 3524545454 CARDINAL

# %%
spacy.explain('GPE')
# Out:
# 'Countries, cities, states'

# %% [markdown]
# Generating Word Frequency

# %%
import nltk
from nltk.probability import FreqDist
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = """NLTK is a leading platform for building Python programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, and an active discussion forum.

Thanks to a hands-on guide introducing programming fundamentals alongside topics in computational linguistics, plus comprehensive API documentation, NLTK is suitable for linguists, engineers, students, educators, researchers, and industry users alike. NLTK is available for Windows, Mac OS X, and Linux. Best of all, NLTK is a free, open source, community-driven project."""

# %%
#Tokenize
word_tokens = nltk.word_tokenize(text)
print(word_tokens)
# Out:
# ['NLTK', 'is', 'a', 'leading', 'platform', 'for', 'building', 'Python', 'programs', 'to', 'work', 'with', 'human', 'language', 'data', '.', 'It', 'provides', 'easy-to-use', 'interfaces', 'to', 'over', '50', 'corpora', 'and', 'lexical', 'resources', 'such', 'as', 'WordNet', ',', 'along', 'with', 'a', 'suite', 'of', 'text', 'processing', 'libraries', 'for', 'classification', ',', 'tokenization', ',', 'stemming', ',', 'tagging', ',', 'parsing', ',', 'and', 'semantic', 'reasoning', ',', 'wrappers', 'for', 'industrial-strength', 'NLP', 'libraries', ',', 'and', 'an', 'active', 'discussion', 'forum', '.', 'Thanks', 'to', 'a', 'hands-on', 'guide', 'introducing', 'programming', 'fundamentals', 'alongside', 'topics', 'in', 'computational', 'linguistics', ',', 'plus', 'comprehensive', 'API', 'documentation', ',', 'NLTK', 'is', 'suitable', 'for', 'linguists', ',', 'engineers', ',', 'students', ',', 'educators', ',', 'researchers', ',', 'and', 'industry', 'users', 'alike', '.', 'NLTK', 'is', 'ava
# ...

# %%
len(word_tokens)
# Out:
# 132

# %%
#Apply Frequency distribution
word2 = FreqDist(word_tokens)
print(word2)
# Out:
# <FreqDist with 87 samples and 132 outcomes>

# %%
len(word2)
# Out:
# 87

# %%
#we see most common 10 words
word2.most_common(10)
# Out:
# [(',', 20),
#  ('for', 5),
#  ('.', 5),
#  ('and', 5),
#  ('NLTK', 4),
#  ('is', 4),
#  ('a', 4),
#  ('to', 3),
#  ('with', 2),
#  ('of', 2)]

# %%
#frequency of a particular word || formula - wordcount/total word
word2.freq("NLTK")
# Out:
# 0.030303030303030304

# %%
import matplotlib.pyplot as plt

# %%
#figure and axis definition
fig, ax = plt.subplots(figsize = (10,5))
word2.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>
