# %%
def raise_to_power(a,b):
  if b==0:
    return 1
  elif b<0:
    return 1 / (a ** abs(b))
  else:
    return a**b

a = float(input("Enter the base number(a): "))
b = int(input("Enter the exponent(b): "))

result = raise_to_power(a, b)
print(f"{a} raised to the power of {b}) is : {result}")
# Out:
# Enter the base number(a): 2
# Enter the exponent(b): 3
# 2.0 raised to the power of 3) is : 8.0

# %%
def raise_to_power(a,b):
  if b==0:
    return 1
  elif b<0:
    return 1 / (a ** abs(b))
  else:
    return a**b

a = float(input("Enter the base number(a): "))
b = int(input("Enter the exponent(b): "))

result = raise_to_power(a, b)
print(f"{a} raised to the power of {b}) is : {result}")
# Out:
# Enter the base number(a): 5
# Enter the exponent(b): 0
# 5.0 raised to the power of 0) is : 1

# %%
def raise_to_power(a,b):
  if b==0:
    return 1
  elif b<0:
    return 1 / (a ** abs(b))
  else:
    return a**b

a = float(input("Enter the base number(a): "))
b = int(input("Enter the exponent(b): "))

result = raise_to_power(a, b)
print(f"{a} raised to the power of {b}) is : {result}")
# Out:
# Enter the base number(a): 2
# Enter the exponent(b): -2
# 2.0 raised to the power of -2) is : 0.25
