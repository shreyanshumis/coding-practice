# %%
#Write a program to compute prev. date given present date and perform decision table testing

# %%
from datetime import datetime, timedelta
from tabulate import tabulate

def get_previous_date(current_date_str):
  current_date = datetime.strptime(current_date_str, "%Y-%m-%d")
  previous_date =current_date - timedelta(days=1)

  return previous_date.strftime("%Y-%m-%d")

test_cases = [
    ("2024-03-01"),
    ("2024-03-01"),
    ("2024-01-01"),
    ("2024-11-13"),
    ("2024-12-01"),
    ("2024-02-28"),
    ("2024-02-28"),
]

results = [(date, get_previous_date(date)) for date in test_cases]

headers= ["Current date", "Previous date"]
print(tabulate(results, headers=headers, tablefmt="grid"))
# Out:
# +----------------+-----------------+
# | Current date   | Previous date   |
# +================+=================+
# | 2024-03-01     | 2024-02-29      |
# +----------------+-----------------+
# | 2024-03-01     | 2024-02-29      |
# +----------------+-----------------+
# | 2024-01-01     | 2023-12-31      |
# +----------------+-----------------+
# | 2024-11-13     | 2024-11-12      |
# +----------------+-----------------+
# | 2024-12-01     | 2024-11-30      |
# +----------------+-----------------+
# | 2024-02-28     | 2024-02-27      |
# +----------------+-----------------+
# | 2024-02-28     | 2024-02-27      |
# +----------------+-----------------+
