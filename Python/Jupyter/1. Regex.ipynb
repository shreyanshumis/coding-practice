# %% [markdown]
# Practical 1

# %%
import re

# %%
str = "Regular Expression Functions"

# %%
x= re.findall("r", str)
print(x)
# Out:
# ['r', 'r']

# %%
x= re.search("r",str)
print(x)
# Out:
# <re.Match object; span=(6, 7), match='r'>

# %%
print(x.start())
# Out:
# 6

# %%
print(x.span)
# Out:
# <built-in method span of re.Match object at 0x7f9b092425c0>

# %%
print(x.string)
# Out:
# Regular Expression Functions

# %%
x = re.split("r", str)
print(x)
# Out:
# ['Regula', ' Exp', 'ession Functions']

# %%
x= re.sub("R", "S", str)
print(x)
# Out:
# Segular Expression Functions

# %%
x = re.match("R", str)
print(x)
# Out:
# <re.Match object; span=(0, 1), match='R'>

# %%
x = re.findall("India", "India, officially the Republic of India (ISO: Bhārat Gaṇarājya),[22] is a country in South Asia. It is the most populous country as well as the seventh-largest country by area,[23] and has a democratic form of government.[24][25][26] Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[j] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is in the vicinity of Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.")
print(x)
# Out:
# ['India', 'India', 'India', 'India', 'India']

# %%
x = re.findall("ଭାରତ", "ଭାରତ ସରକାରୀ ସ୍ତରରେ ଏକ ଗଣରାଜ୍ୟ ଓ ଦକ୍ଷିଣ ଏସିଆର ଏକ ଦେଶ । ଏହା ଭୌଗୋଳିକ ଆୟତନ ଅନୁସାରେ ବିଶ୍ୱର ସପ୍ତମ ଓ ଜନସଂଖ୍ୟା ଅନୁସାରେ ବିଶ୍ୱର ପ୍ରଥମ ବୃହତ୍ତମ ଦେଶ । ଏହା ବିଶ୍ୱର ବୃହତ୍ତମ ଗଣତନ୍ତ୍ର ରୁପରେ ପରିଚିତ । ଏହାର ଉତ୍ତରରେ ଉଚ୍ଚ ଏବଂ ବହୁଦୂର ଯାଏ ଲମ୍ବିଥିବା ହିମାଳୟ, ଦକ୍ଷିଣରେ ଭାରତ ମହାସାଗର, ପୂର୍ବରେ ବଙ୍ଗୋପସାଗର ଓ ପଶ୍ଚିମରେ ଆରବସାଗର ରହିଛି । ଏହି ବିଶାଳ ଭୂଖଣ୍ଡରେ 28 ଗୋଟି ରାଜ୍ୟ ଓ ୮ଟି କେନ୍ଦ୍ର-ଶାସିତ ଅଞ୍ଚଳ ରହିଛି । ଭାରତର ପଡ଼ୋଶୀ ଦେଶମାନଙ୍କ ମଧ୍ୟରେ, ଉତ୍ତରରେ ଚୀନ, ନେପାଳ ଓ ଭୁଟାନ, ପଶ୍ଚିମରେ ପାକିସ୍ତାନ, ପୂର୍ବରେ ବଙ୍ଗଳାଦେଶ ଓ ମିଆଁମାର, ଏବଂ ଦକ୍ଷିଣରେ ଶ୍ରୀଲଙ୍କା ଅବସ୍ଥିତ ।")
print(x)
# Out:
# ['ଭାରତ', 'ଭାରତ', 'ଭାରତ']

# %% [markdown]
# --------------

# %%
x= re.findall("re",str)
print(x)
# Out:
# ['re']

# %%
x= re.findall("2",str)
print(x)
# Out:
# []

# %%
x= re.findall("e",str)
print(x)
# Out:
# ['e', 'e']

# %%
x=re.search("r",str)
print(x)
# Out:
# <re.Match object; span=(6, 7), match='r'>

# %%
x=re.search("Regular",str)
print(x.span())
# Out:
# (0, 7)

# %%
x=re.split("",str)
print(x)
# Out:
# ['', 'R', 'e', 'g', 'u', 'l', 'a', 'r', ' ', 'E', 'x', 'p', 'r', 'e', 's', 's', 'i', 'o', 'n', ' ', 'F', 'u', 'n', 'c', 't', 'i', 'o', 'n', 's', '']

# %%
x=re.split(" ",str)
print(x)
# Out:
# ['Regular', 'Expression', 'Functions']

# %%
x=re.split("",str,7)
print(x)
# Out:
# ['', 'R', 'e', 'g', 'u', 'l', 'a', 'r Expression Functions']

# %%
x=re.split("r",str)
print(x)
# Out:
# ['Regula', ' Exp', 'ession Functions']

# %%
str2="Understanding Development"
x=re.split(" ",str2)
print(x)
# Out:
# ['Understanding', 'Development']

# %%
x=re.split("",str2)
print(x)
# Out:
# ['', 'U', 'n', 'd', 'e', 'r', 's', 't', 'a', 'n', 'd', 'i', 'n', 'g', ' ', 'D', 'e', 'v', 'e', 'l', 'o', 'p', 'm', 'e', 'n', 't', '']

# %% [markdown]
# ----------
